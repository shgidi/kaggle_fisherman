# %% [markdown]
# ## some playing with fisheries

# %%
path='/mnt/kaggle_fisherman/'

# %%
cd /mnt/kaggle_fisherman/train
# Out:
# /mnt/kaggle_fisherman/train

# %%
import glob
g=glob.glob('*/*.jpg')

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
from PIL import Image
imgs=[np.array(Image.open(file)) for file in g]

# %%
imgs[0].shape[:2]
# Out:
# (720,)

# %%
g[0].split('/')[0]
# Out:
# 'NoF'

# %%
sizes=[im.shape[:2] for im in imgs]
types=[file.split('/')[0] for file in g]

# %%
sizes=[str(im.shape[:2]) for im in imgs]

# %%
import pandas as pd
df=pd.DataFrame({'types':types_num,'sizes':sizes_num})

# %%
df.plot.scatter('types','sizes')
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
from sklearn.preprocessing import LabelEncoder
le_1=LabelEncoder()
sizes_num=le_1.fit_transform(sizes)
le_2=LabelEncoder()
types_num=le_2.fit_transform(types)

# %%
df
# Out:
#       sizes  types
# 0         3      4
# 1         3      4
# 2         3      4
# 3         3      4
# 4         3      4
# 5         3      4
# 6         3      4
# 7         3      4
# 8         9      4
# 9         4      4
# 10        2      4
# 11        3      4
# 12        3      4
# 13        0      4
# 14        2      4
# 15        2      4
# 16        2      4
# 17        3      4
# 18        3      4
# 19        3      4
# 20        4      4
# 21        2      4
# 22        5      4
# 23        3      4
# 24        2      4
# 25        2      4
# 26        3      4
# 27        2      4
# 28        5      4
# 29        6      4
# ...     ...    ...
# 3747      3      5
# 3748      3      5
# 3749      8      5
# 3750      3      5
# 3751      3      5
# 3752      3      5
# 3753      3      5
# 3754      3      5
# 3755      4      5
# 3756      3      5
# 3757      8      5
# 3758      3      5
# 3759      3      5
# 3760      3      5
# 3761      3      5
# ...

# %%
grouped=df.groupby(['sizes','types'])
grouped_df=grouped.size().reset_index()

# %%
plt.scatter(grouped_df['sizes'],grouped_df['types'],s=grouped_df[0])
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
import seaborn as sns

# %%
# %matplotlib inline
sns.stripplot(x='types',y='sizes',data=df, jitter=True);
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
df.columns=['ship','type']

# %%
df.groupby('ship').count().plot.bar(figsize=(12,6),legend=False,title='Ship inferred frequency')
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
np.random.choice(3200,9)
# Out:
# array([1744,  688,  972,  409, 2861,  127,  122,  122, 1515])

# %%
choices
# Out:
# range(0, 9)

# %%
image_id=0
size=150
fig = plt.figure(figsize=(20,12))
n_images_per_row=3
choices=np.random.choice(3200,9)
for i,ids in enumerate(choices):
    #a=
    ax = fig.add_subplot(4,n_images_per_row,i+1)
    plt.grid(False)
    #plt.imshow(lion_patches[j])
    plt.imshow(imgs[ids])
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
